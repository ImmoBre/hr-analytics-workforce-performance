# %% [markdown]
# # HR Analytics: Workforce Performance & Employee Insights
#
# ## 01 - Data Understanding
#
# ### Project Overview
#
# This project analyzes employee workforce data to uncover insights related to employee performance, compensation, engagement, absenteeism, recruitment, and termination patterns.
#
# The goal is to support HR decision-making through data analysis, SQL business questions, and an executive Power BI dashboard.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.float_format", "{:,.2f}".format)

# %%
df = pd.read_csv("../data/HRDataset_v14.csv")

df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# 0            1       5            4                       0   62506      0
# 1            5       3            3                       0  104437      1
# 2            5       5            3                       0   64955      1
# 3            1       5            3                       0   64991      0
# 4            5       5            3                       0   50825      1
#
# ...

# %%
df.shape
# Out:
# (311, 36)

# %% [markdown]
# #### Dataset Dimensions
#
# The first step is to understand the size of the dataset by identifying the number of rows (observations) and columns (features).

# %%
print(f"Number of Rows: {df.shape[0]}")
print(f"Number of Columns: {df.shape[1]}")
# Out:
# Number of Rows: 311
# Number of Columns: 36

# %% [markdown]
# #### Dataset Columns
#
# Display all available variables contained in the dataset.

# %%
df.columns.tolist()
# Out:
# ['Employee_Name',
#  'EmpID',
#  'MarriedID',
#  'MaritalStatusID',
#  'GenderID',
#  'EmpStatusID',
#  'DeptID',
#  'PerfScoreID',
#  'FromDiversityJobFairID',
#  'Salary',
#  'Termd',
#  'PositionID',
#  'Position',
#  'State',
#  'Zip',
#  'DOB',
#  'Sex',
#  'MaritalDesc',
#  'CitizenDesc',
#  'HispanicLatino',
#  'RaceDesc',
#  'DateofHire',
#  'DateofTermination',
#  'TermReason',
#  'EmploymentStatus',
#  'Department',
#  'ManagerName',
#  'ManagerID',
#  'RecruitmentSource',
#  'PerformanceScore',
#  'EngagementSurvey',
#  'EmpSatisfaction',
#  'SpecialProjectsCount',
#  'LastPerformanceReview_Date',
#  'DaysLateLast30',
#  'Absences']

# %% [markdown]
# #### Data Types
#
# Understanding the data type of each variable helps identify numerical, categorical, and date-related features.

# %%
df.dtypes
# Out:
# Employee_Name                  object
# EmpID                           int64
# MarriedID                       int64
# MaritalStatusID                 int64
# GenderID                        int64
# EmpStatusID                     int64
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID          int64
# Salary                          int64
# Termd                           int64
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# ...

# %% [markdown]
# #### Dataset Information
#
# The dataset information provides the number of non-null values, memory usage, and data types for every feature.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %% [markdown]
# #### Statistical Summary
#
# Generate descriptive statistics for all numerical variables.

# %%
df.describe()
# Out:
#           EmpID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  DeptID  \
# count    311.00     311.00           311.00    311.00       311.00  311.00
# mean  10,156.00       0.40             0.81      0.43         2.39    4.61
# std       89.92       0.49             0.94      0.50         1.79    1.08
# min   10,001.00       0.00             0.00      0.00         1.00    1.00
# 25%   10,078.50       0.00             0.00      0.00         1.00    5.00
# 50%   10,156.00       0.00             1.00      0.00         1.00    5.00
# 75%   10,233.50       1.00             1.00      1.00         5.00    5.00
# max   10,311.00       1.00             4.00      1.00         5.00    6.00
#
#        PerfScoreID  FromDiversityJobFairID     Salary  Termd  PositionID  \
# count       311.00                  311.00     311.00 311.00      311.00
# mean          2.98                    0.09  69,020.68   0.33       16.85
# ...

# %% [markdown]
# #### Categorical Variables Summary
#
# Display descriptive statistics for categorical features.

# %%
df.describe(include="object")
# Out:
#               Employee_Name                 Position State       DOB  Sex  \
# count                   311                      311   311       311  311
# unique                  311                       32    28       307    2
# top     Adinolfi, Wilson  K  Production Technician I    MA  09/09/65    F
# freq                      1                      137   276         2  176
#
#        MaritalDesc CitizenDesc HispanicLatino RaceDesc DateofHire  \
# count          311         311            311      311        311
# unique           5           3              4        6        101
# top         Single  US Citizen             No    White  1/10/2011
# freq           137         295            282      187         14
#
#        DateofTermination         TermReason EmploymentStatus  \
# count                104                311              311
# unique                96                 18                3
# top            8/19/2018  N/A-StillEmployed           Active
# ...

# %% [markdown]
# #### Random Sample
#
# Display a random sample of employees to better understand the structure of the dataset.

# %%
df.sample(5, random_state=42)
# Out:
#           Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 290       Vega, Vincent  10144          0                2         1
# 9    Bacong, Alejandro   10250          0                2         1
# 57      Costello, Frank  10193          1                1         1
# 60       Daneault, Lynn  10099          0                0         0
# 25         Booth, Frank  10199          0                0         1
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# 290            1       5            3                       0   88976      0
# 9              1       3            3                       0   50178      0
# 57             1       3            3                       0   83552      0
# 60             1       6            3                       0   65729      0
# 25             4       3            3                       0  103613      1
#
#      PositionID              Position State   Zip       DOB Sex MaritalDesc  \
# ...

# %% [markdown]
# #### Initial Observations
#
# The dataset contains 311 employee records and 36 variables covering employee demographics, employment status, compensation, department, position, recruitment source, performance, engagement, satisfaction, absences, and termination information.
#
# The dataset supports several business analysis areas:
#
# - Workforce demographics
# - Employee attrition and termination analysis
# - Department and position analysis
# - Salary and compensation analysis
# - Recruitment source effectiveness
# - Employee performance and satisfaction
# - Absenteeism and lateness patterns

# %% [markdown]
# #### Notebook Summary
#
# This notebook introduced the dataset and reviewed its structure, variables, data types, and initial statistical summaries.
#
# The next notebook will focus on data quality assessment, including missing values, duplicate records, date formatting, and consistency checks.
